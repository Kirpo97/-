# %%
# ПОПОВ КМ - ЛАБОРАТОРНАЯ РАБОТА 1 - SOAP-Сервисы

from zeep import Client

Services= {
    "Temperature":"https://www.w3schools.com/xml/tempconvert.asmx",
    "Continents":"http://webservices.oorsprong.org/websamples.countryinfo/CountryInfoService.wso"
}

# Получение доступных категорий
def get_cat(input_services):
    print("\nДоспупные сервисы:")
    for service_name in Services:
        print(service_name)    
    print()
    if input_services == None:
        input_services = input("Введите сервис и нажмите Enter (для выхода оставте поле пустым) \n")  
    print('\nВведён метод: ', input_services)
    return input_services    

def get_method(set_services, input_method=None): 
    print("\nДоступные методы для выбранного сервиса:")
    client = Client(Services[set_services]+'?WSDL')
    services = client.service
    methods = services.__dir__()
    for method in methods:
        print(f"- {method}")
    if input_method == None:
        input_method = input("\nВведите метод: ")
    print('\nВведён метод :', input_method)
    return input_method

def init(input_services=None, input_method=None, value=None):
    try:           
        cat = get_cat(input_services)
        try:
            method = get_method(cat, input_method)
            try: 
                if value == None:  
                    value = input("Введите значение (для списка оставте поле пустым) и нажмине Enter: \n") 
                client = Client(Services[cat]+'?WSDL')            
                result = getattr(client.service, input_method)(value)   
                print('Результат: ', result)    
            except:
                client = Client(Services[cat]+'?WSDL')            
                result = getattr(client.service, method)()  
                print('Результат: ', result)        
        except:
            print("Ошибка. Метод не поддерживается.\n")
    except:
        print("Ошибка. Данные введены некоректно.\n")

if __name__ == "__main__":

    print('\nТест на запросы конвертации температуры: \n')
    
    # Если параметры не вводить, функция вернёт список доступных сервисов
    init()
    
    # Если не вводить метод, функция вернёт список методов сервиса
    init(input_services = 'Temperature')
    
    # Тест сервиса температуры
    init(input_services = 'Temperature', input_method='CelsiusToFahrenheit', value='10')
    init(input_services = 'Temperature', input_method='FahrenheitToCelsius', value='100')
    
    # Тест на ввод неправильных значений
    init(input_services = 'Temperature', input_method='CelsiusToFahrenheit', value='')
    init(input_services = 'Temperature', input_method='FahrenheitToCelsius', value='')
    init(input_services = 'Temperature', input_method='123', value='55')
    init(input_services = '123', input_method='', value='')

    # Тест сервиса Континенты
    print('\nТест сервис континенты: \n')
    init(input_services = 'Continents', input_method='ListOfContinentsByName', value='')
    init(input_services = 'Continents', input_method='ListOfContinentsByCode', value='')
    init(input_services = 'Continents', input_method='ListOfCurrenciesByName', value='')
# Out:
# Тест на запросы конвертации температуры:
#
#
# Доспупные сервисы:
# Temperature
# Continents
#
#
# Введён метод:
#
# Доступные методы для выбранного сервиса:
# Ошибка. Метод не поддерживается.
#
#
# Доспупные сервисы:
# Temperature
# Continents
#
#
# Введён метод:  Temperature
#
# Доступные методы для выбранного сервиса:
# Forcing soap:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing http:address location to HTTPS
# - __class__
# - __delattr__
# - __dir__
# - __doc__
# - __eq__
# - __format__
# - __ge__
# - __get__
# - __getattribute__
# - __gt__
# - __hash__
# - __init__
# - __init_subclass__
# - __le__
# - __lt__
# - __ne__
# - __new__
# - __reduce__
# - __reduce_ex__
# - __repr__
# - __self__
# - __self_class__
# - __setattr__
# - __sizeof__
# - __str__
# - __subclasshook__
# - __thisclass__
# - FahrenheitToCelsius
# - CelsiusToFahrenheit
#
# Введён метод :
# Forcing soap:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing http:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing http:address location to HTTPS
# Ошибка. Метод не поддерживается.
#
#
# Доспупные сервисы:
# Temperature
# Continents
#
#
# Введён метод:  Temperature
#
# Доступные методы для выбранного сервиса:
# Forcing soap:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing http:address location to HTTPS
# - __class__
# - __delattr__
# - __dir__
# - __doc__
# - __eq__
# - __format__
# - __ge__
# - __get__
# - __getattribute__
# - __gt__
# - __hash__
# - __init__
# - __init_subclass__
# - __le__
# - __lt__
# - __ne__
# - __new__
# - __reduce__
# - __reduce_ex__
# - __repr__
# - __self__
# - __self_class__
# - __setattr__
# - __sizeof__
# - __str__
# - __subclasshook__
# - __thisclass__
# - FahrenheitToCelsius
# - CelsiusToFahrenheit
#
# Введён метод : CelsiusToFahrenheit
# Forcing soap:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing http:address location to HTTPS
# Результат:  50
#
# Доспупные сервисы:
# Temperature
# Continents
#
#
# Введён метод:  Temperature
#
# Доступные методы для выбранного сервиса:
# Forcing soap:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing http:address location to HTTPS
# - __class__
# - __delattr__
# - __dir__
# - __doc__
# - __eq__
# - __format__
# - __ge__
# - __get__
# - __getattribute__
# - __gt__
# - __hash__
# - __init__
# - __init_subclass__
# - __le__
# - __lt__
# - __ne__
# - __new__
# - __reduce__
# - __reduce_ex__
# - __repr__
# - __self__
# - __self_class__
# - __setattr__
# - __sizeof__
# - __str__
# - __subclasshook__
# - __thisclass__
# - FahrenheitToCelsius
# - CelsiusToFahrenheit
#
# Введён метод : FahrenheitToCelsius
# Forcing soap:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing http:address location to HTTPS
# Результат:  37.7777777777778
#
# Доспупные сервисы:
# Temperature
# Continents
#
#
# Введён метод:  Temperature
#
# Доступные методы для выбранного сервиса:
# Forcing soap:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing http:address location to HTTPS
# - __class__
# - __delattr__
# - __dir__
# - __doc__
# - __eq__
# - __format__
# - __ge__
# - __get__
# - __getattribute__
# - __gt__
# - __hash__
# - __init__
# - __init_subclass__
# - __le__
# - __lt__
# - __ne__
# - __new__
# - __reduce__
# - __reduce_ex__
# - __repr__
# - __self__
# - __self_class__
# - __setattr__
# - __sizeof__
# - __str__
# - __subclasshook__
# - __thisclass__
# - FahrenheitToCelsius
# - CelsiusToFahrenheit
#
# Введён метод : CelsiusToFahrenheit
# Forcing soap:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing http:address location to HTTPS
# Результат:  Error
#
# Доспупные сервисы:
# Temperature
# Continents
#
#
# Введён метод:  Temperature
#
# Доступные методы для выбранного сервиса:
# Forcing soap:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing http:address location to HTTPS
# - __class__
# - __delattr__
# - __dir__
# - __doc__
# - __eq__
# - __format__
# - __ge__
# - __get__
# - __getattribute__
# - __gt__
# - __hash__
# - __init__
# - __init_subclass__
# - __le__
# - __lt__
# - __ne__
# - __new__
# - __reduce__
# - __reduce_ex__
# - __repr__
# - __self__
# - __self_class__
# - __setattr__
# - __sizeof__
# - __str__
# - __subclasshook__
# - __thisclass__
# - FahrenheitToCelsius
# - CelsiusToFahrenheit
#
# Введён метод : FahrenheitToCelsius
# Forcing soap:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing http:address location to HTTPS
# Результат:  Error
#
# Доспупные сервисы:
# Temperature
# Continents
#
#
# Введён метод:  Temperature
#
# Доступные методы для выбранного сервиса:
# Forcing soap:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing http:address location to HTTPS
# - __class__
# - __delattr__
# - __dir__
# - __doc__
# - __eq__
# - __format__
# - __ge__
# - __get__
# - __getattribute__
# - __gt__
# - __hash__
# - __init__
# - __init_subclass__
# - __le__
# - __lt__
# - __ne__
# - __new__
# - __reduce__
# - __reduce_ex__
# - __repr__
# - __self__
# - __self_class__
# - __setattr__
# - __sizeof__
# - __str__
# - __subclasshook__
# - __thisclass__
# - FahrenheitToCelsius
# - CelsiusToFahrenheit
#
# Введён метод : 123
# Forcing soap:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing http:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing soap:address location to HTTPS
# Forcing http:address location to HTTPS
# Ошибка. Метод не поддерживается.
#
#
# Доспупные сервисы:
# Temperature
# Continents
#
#
# Введён метод:  123
#
# Доступные методы для выбранного сервиса:
# Ошибка. Метод не поддерживается.
#
#
# Тест сервис континенты:
#
#
# Доспупные сервисы:
# Temperature
# Continents
#
#
# Введён метод:  Continents
#
# Доступные методы для выбранного сервиса:
# - __class__
# - __delattr__
# - __dir__
# - __doc__
# - __eq__
# - __format__
# - __ge__
# - __get__
# - __getattribute__
# - __gt__
# - __hash__
# - __init__
# - __init_subclass__
# - __le__
# - __lt__
# - __ne__
# - __new__
# - __reduce__
# - __reduce_ex__
# - __repr__
# - __self__
# - __self_class__
# - __setattr__
# - __sizeof__
# - __str__
# - __subclasshook__
# - __thisclass__
# - ListOfContinentsByName
# - ListOfContinentsByCode
# - ListOfCurrenciesByName
# - ListOfCurrenciesByCode
# - CurrencyName
# - ListOfCountryNamesByCode
# - ListOfCountryNamesByName
# - ListOfCountryNamesGroupedByContinent
# - CountryName
# - CountryISOCode
# - CapitalCity
# - CountryCurrency
# - CountryFlag
# - CountryIntPhoneCode
# - FullCountryInfo
# - FullCountryInfoAllCountries
# - CountriesUsingCurrency
# - ListOfLanguagesByName
# - ListOfLanguagesByCode
# - LanguageName
# - LanguageISOCode
#
# Введён метод : ListOfContinentsByName
# Результат:  [{
#     'sCode': 'AF',
#     'sName': 'Africa'
# }, {
#     'sCode': 'AN',
#     'sName': 'Antarctica'
# }, {
#     'sCode': 'AS',
#     'sName': 'Asia'
# }, {
#     'sCode': 'EU',
#     'sName': 'Europe'
# }, {
#     'sCode': 'OC',
#     'sName': 'Ocenania'
# }, {
#     'sCode': 'AM',
#     'sName': 'The Americas'
# }]
#
# Доспупные сервисы:
# Temperature
# Continents
#
#
# Введён метод:  Continents
#
# Доступные методы для выбранного сервиса:
# - __class__
# - __delattr__
# - __dir__
# - __doc__
# - __eq__
# - __format__
# - __ge__
# - __get__
# - __getattribute__
# - __gt__
# - __hash__
# - __init__
# - __init_subclass__
# - __le__
# - __lt__
# - __ne__
# - __new__
# - __reduce__
# - __reduce_ex__
# - __repr__
# - __self__
# - __self_class__
# - __setattr__
# - __sizeof__
# - __str__
# - __subclasshook__
# - __thisclass__
# - ListOfContinentsByName
# - ListOfContinentsByCode
# - ListOfCurrenciesByName
# - ListOfCurrenciesByCode
# - CurrencyName
# - ListOfCountryNamesByCode
# - ListOfCountryNamesByName
# - ListOfCountryNamesGroupedByContinent
# - CountryName
# - CountryISOCode
# - CapitalCity
# - CountryCurrency
# - CountryFlag
# - CountryIntPhoneCode
# - FullCountryInfo
# - FullCountryInfoAllCountries
# - CountriesUsingCurrency
# - ListOfLanguagesByName
# - ListOfLanguagesByCode
# - LanguageName
# - LanguageISOCode
#
# Введён метод : ListOfContinentsByCode
# Результат:  [{
#     'sCode': 'AF',
#     'sName': 'Africa'
# }, {
#     'sCode': 'AM',
#     'sName': 'The Americas'
# }, {
#     'sCode': 'AN',
#     'sName': 'Antarctica'
# }, {
#     'sCode': 'AS',
#     'sName': 'Asia'
# }, {
#     'sCode': 'EU',
#     'sName': 'Europe'
# }, {
#     'sCode': 'OC',
#     'sName': 'Ocenania'
# }]
#
# Доспупные сервисы:
# Temperature
# Continents
#
#
# Введён метод:  Continents
#
# Доступные методы для выбранного сервиса:
# - __class__
# - __delattr__
# - __dir__
# - __doc__
# - __eq__
# - __format__
# - __ge__
# - __get__
# - __getattribute__
# - __gt__
# - __hash__
# - __init__
# - __init_subclass__
# - __le__
# - __lt__
# - __ne__
# - __new__
# - __reduce__
# - __reduce_ex__
# - __repr__
# - __self__
# - __self_class__
# - __setattr__
# - __sizeof__
# - __str__
# - __subclasshook__
# - __thisclass__
# - ListOfContinentsByName
# - ListOfContinentsByCode
# - ListOfCurrenciesByName
# - ListOfCurrenciesByCode
# - CurrencyName
# - ListOfCountryNamesByCode
# - ListOfCountryNamesByName
# - ListOfCountryNamesGroupedByContinent
# - CountryName
# - CountryISOCode
# - CapitalCity
# - CountryCurrency
# - CountryFlag
# - CountryIntPhoneCode
# - FullCountryInfo
# - FullCountryInfoAllCountries
# - CountriesUsingCurrency
# - ListOfLanguagesByName
# - ListOfLanguagesByCode
# - LanguageName
# - LanguageISOCode
#
# Введён метод : ListOfCurrenciesByName
# Результат:  [{
#     'sISOCode': 'AFA',
#     'sName': 'Afghanis'
# }, {
#     'sISOCode': 'DZD',
#     'sName': 'Algeria Dinars'
# }, {
#     'sISOCode': 'MGA',
#     'sName': 'Ariary'
# }, {
#     'sISOCode': 'AWG',
#     'sName': 'Aruba Guilders (also called Florins)'
# }, {
#     'sISOCode': 'AUD',
#     'sName': 'Australian Dollars'
# }, {
#     'sISOCode': 'BSD',
#     'sName': 'Bahamas Dollars'
# }, {
#     'sISOCode': 'BHD',
#     'sName': 'Bahrain Dinars'
# }, {
#     'sISOCode': 'THB',
#     'sName': 'Baht'
# }, {
#     'sISOCode': 'PAB',
#     'sName': 'Balboa'
# }, {
#     'sISOCode': 'BBD',
#     'sName': 'Barbados Dollars'
# }, {
#     'sISOCode': 'BZD',
#     'sName': 'Belize Dollars'
# }, {
#     'sISOCode': 'BMD',
#     'sName': 'Bermuda Dollars'
# }, {
#     'sISOCode': 'ETB',
#     'sName': 'Birr'
# }, {
#     'sISOCode': 'VEB',
#     'sName': 'Bolivares'
# }, {
#     'sISOCode': 'BOB',
#     'sName': 'Bolivianos'
# }, {
#     'sISOCode': 'BRL',
#     'sName': 'Brazil Real'
# }, {
#     'sISOCode': 'BND',
#     'sName': 'Brunei Dollars'
# }, {
#     'sISOCode': 'CAD',
#     'sName': 'Canadian Dollars'
# }, {
#     'sISOCode': 'KYD',
#     'sName': 'Cayman Island Dollars'
# }, {
#     'sISOCode': 'GHC',
#     'sName': 'Cedis'
# }, {
#     'sISOCode': 'CRC',
#     'sName': 'Colones'
# }, {
#     'sISOCode': 'SVC',
#     'sName': 'Colones'
# }, {
#     'sISOCode': 'XAF',
#     'sName': 'Communauté Financière Africaine Francs'
# }, {
#     'sISOCode': 'XOF',
#     'sName': 'Communauté Financière Africaine Francs'
# }, {
#     'sISOCode': 'XPF',
#     'sName': 'Comptoirs Franþais du Pacifique Francs'
# }, {
#     'sISOCode': 'CDF',
#     'sName': 'Congolese Francs'
# }, {
#     'sISOCode': 'BAM',
#     'sName': 'Convertible Marka'
# }, {
#     'sISOCode': 'NIO',
#     'sName': 'Cordobas'
# }, {
#     'sISOCode': 'GMD',
#     'sName': 'Dalasi'
# }, {
#     'sISOCode': 'MKD',
#     'sName': 'Denars'
# }, {
#     'sISOCode': 'CSD',
#     'sName': 'Dinars'
# }, {
#     'sISOCode': 'IQD',
#     'sName': 'Dinars'
# }, {
#     'sISOCode': 'JOD',
#     'sName': 'Dinars'
# }, {
#     'sISOCode': 'KWD',
#     'sName': 'Dinars'
# }, {
#     'sISOCode': 'LYD',
#     'sName': 'Dinars'
# }, {
#     'sISOCode': 'SDD',
#     'sName': 'Dinars'
# }, {
#     'sISOCode': 'TND',
#     'sName': 'Dinars'
# }, {
#     'sISOCode': 'AED',
#     'sName': 'Dirhams'
# }, {
#     'sISOCode': 'STD',
#     'sName': 'Dobras'
# }, {
#     'sISOCode': 'FJD',
#     'sName': 'Dollars'
# }, {
#     'sISOCode': 'GYD',
#     'sName': 'Dollars'
# }, {
#     'sISOCode': 'JMD',
#     'sName': 'Dollars'
# }, {
#     'sISOCode': 'LRD',
#     'sName': 'Dollars'
# }, {
#     'sISOCode': 'NAD',
#     'sName': 'Dollars'
# }, {
#     'sISOCode': 'SBD',
#     'sName': 'Dollars'
# }, {
#     'sISOCode': 'SGD',
#     'sName': 'Dollars'
# }, {
#     'sISOCode': 'SRD',
#     'sName': 'Dollars'
# }, {
#     'sISOCode': 'TTD',
#     'sName': 'Dollars'
# }, {
#     'sISOCode': 'USD',
#     'sName': 'Dollars'
# }, {
#     'sISOCode': 'VND',
#     'sName': 'Dong'
# }, {
#     'sISOCode': 'AMD',
#     'sName': 'Drams'
# }, {
#     'sISOCode': 'XCD',
#     'sName': 'East Caribbean Dollars'
# }, {
#     'sISOCode': 'SZL',
#     'sName': 'Emalangeni'
# }, {
#     'sISOCode': 'CVE',
#     'sName': 'Escudos'
# }, {
#     'sISOCode': 'EUR',
#     'sName': 'Euro'
# }, {
#     'sISOCode': 'FKP',
#     'sName': 'Falklands Pounds'
# }, {
#     'sISOCode': 'HUF',
#     'sName': 'Forint'
# }, {
#     'sISOCode': 'BIF',
#     'sName': 'Francs'
# }, {
#     'sISOCode': 'DJF',
#     'sName': 'Francs'
# }, {
#     'sISOCode': 'GNF',
#     'sName': 'Francs'
# }, {
#     'sISOCode': 'KMF',
#     'sName': 'Francs'
# }, {
#     'sISOCode': 'GIP',
#     'sName': 'Gibraltar Pounds'
# }, {
#     'sISOCode': 'XAU',
#     'sName': 'Gold Ounces'
# }, {
#     'sISOCode': 'HTG',
#     'sName': 'Gourdes'
# }, {
#     'sISOCode': 'GBP',
#     'sName': 'Great Brittain Pounds'
# }, {
#     'sISOCode': 'PYG',
#     'sName': 'Guarani'
# }, {
#     'sISOCode': 'HKD',
#     'sName': 'Hong Kong Dollars'
# }, {
#     'sISOCode': 'UAH',
#     'sName': 'Hryvnia'
# }, {
#     'sISOCode': 'XDR',
#     'sName': 'International Monetary Fund (IMF) Special Drawing Rights'
# }, {
#     'sISOCode': 'PGK',
#     'sName': 'Kina'
# }, {
#     'sISOCode': 'LAK',
#     'sName': 'Kips'
# }, {
#     'sISOCode': 'CZK',
#     'sName': 'Koruny'
# }, {
#     'sISOCode': 'SKK',
#     'sName': 'Koruny'
# }, {
#     'sISOCode': 'NOK',
#     'sName': 'Krone'
# }, {
#     'sISOCode': 'DKK',
#     'sName': 'Kroner'
# }, {
#     'sISOCode': 'SEK',
#     'sName': 'Kronor'
# }, {
#     'sISOCode': 'ISK',
#     'sName': 'Kronur'
# }, {
#     'sISOCode': 'EEK',
#     'sName': 'Krooni'
# }, {
#     'sISOCode': 'HRK',
#     'sName': 'Kuna'
# }, {
#     'sISOCode': 'ZMK',
#     'sName': 'Kwacha'
# }, {
#     'sISOCode': 'MWK',
#     'sName': 'Kwachas'
# }, {
#     'sISOCode': 'AOA',
#     'sName': 'Kwanza'
# }, {
#     'sISOCode': 'MMK',
#     'sName': 'Kyats'
# }, {
#     'sISOCode': 'GEL',
#     'sName': 'Lari'
# }, {
#     'sISOCode': 'LVL',
#     'sName': 'Lati'
# }, {
#     'sISOCode': 'MDL',
#     'sName': 'Lei'
# }, {
#     'sISOCode': 'ALL',
#     'sName': 'Leke'
# }, {
#     'sISOCode': 'HNL',
#     'sName': 'Lempiras'
# }, {
#     'sISOCode': 'SLL',
#     'sName': 'Leones'
# }, {
#     'sISOCode': 'BGN',
#     'sName': 'Leva'
# }, {
#     'sISOCode': 'TRL',
#     'sName': 'Liras [being phased out]'
# }, {
#     'sISOCode': 'MTL',
#     'sName': 'Liri'
# }, {
#     'sISOCode': 'LTL',
#     'sName': 'Litai'
# }, {
#     'sISOCode': 'SPL',
#     'sName': 'Luigini'
# }, {
#     'sISOCode': 'LSL',
#     'sName': 'Maloti'
# }, {
#     'sISOCode': 'AZM',
#     'sName': 'Manats'
# }, {
#     'sISOCode': 'TMM',
#     'sName': 'Manats'
# }, {
#     'sISOCode': 'MZM',
#     'sName': 'Meticais'
# }, {
#     'sISOCode': 'MAD',
#     'sName': 'Morocco Dirhams'
# }, {
#     'sISOCode': 'NGN',
#     'sName': 'Nairas'
# }, {
#     'sISOCode': 'ERN',
#     'sName': 'Nakfa'
# }, {
#     'sISOCode': 'NPR',
#     'sName': 'Nepal Rupees'
# }, {
#     'sISOCode': 'ANG',
#     'sName': 'Netherlands Antilles Guilders (also called Florins)'
# }, {
#     'sISOCode': 'TWD',
#     'sName': 'New Dollars'
# }, {
#     'sISOCode': 'RON',
#     'sName': 'New Lei'
# }, {
#     'sISOCode': 'TRY',
#     'sName': 'New Lira'
# }, {
#     'sISOCode': 'ILS',
#     'sName': 'New Shekels'
# }, {
#     'sISOCode': 'NZD',
#     'sName': 'New Zealand Dollars'
# }, {
#     'sISOCode': 'BTN',
#     'sName': 'Ngultrum'
# }, {
#     'sISOCode': None,
#     'sName': 'No Universal Currency'
# }, {
#     'sISOCode': 'PEN',
#     'sName': 'Nuevos Soles'
# }, {
#     'sISOCode': 'MRO',
#     'sName': 'Ouguiyas'
# }, {
#     'sISOCode': 'TOP',
#     'sName': "Pa'anga"
# }, {
#     'sISOCode': 'XPD',
#     'sName': 'Palladium Ounces'
# }, {
#     'sISOCode': 'MOP',
#     'sName': 'Patacas'
# }, {
#     'sISOCode': 'ARS',
#     'sName': 'Pesos'
# }, {
#     'sISOCode': 'CLP',
#     'sName': 'Pesos'
# }, {
#     'sISOCode': 'COP',
#     'sName': 'Pesos'
# }, {
#     'sISOCode': 'CUP',
#     'sName': 'Pesos'
# }, {
#     'sISOCode': 'DOP',
#     'sName': 'Pesos'
# }, {
#     'sISOCode': 'MXN',
#     'sName': 'Pesos'
# }, {
#     'sISOCode': 'PHP',
#     'sName': 'Pesos'
# }, {
#     'sISOCode': 'UYU',
#     'sName': 'Pesos'
# }, {
#     'sISOCode': 'XPT',
#     'sName': 'Platinum Ounces'
# }, {
#     'sISOCode': 'CYP',
#     'sName': 'Pounds'
# }, {
#     'sISOCode': 'EGP',
#     'sName': 'Pounds'
# }, {
#     'sISOCode': 'GGP',
#     'sName': 'Pounds'
# }, {
#     'sISOCode': 'IMP',
#     'sName': 'Pounds'
# }, {
#     'sISOCode': 'JEP',
#     'sName': 'Pounds'
# }, {
#     'sISOCode': 'LBP',
#     'sName': 'Pounds'
# }, {
#     'sISOCode': 'SHP',
#     'sName': 'Pounds'
# }, {
#     'sISOCode': 'SYP',
#     'sName': 'Pounds'
# }, {
#     'sISOCode': 'BWP',
#     'sName': 'Pulas'
# }, {
#     'sISOCode': 'GTQ',
#     'sName': 'Quetzales'
# }, {
#     'sISOCode': 'IRR',
#     'sName': 'Rials'
# }, {
#     'sISOCode': 'OMR',
#     'sName': 'Rials'
# }, {
#     'sISOCode': 'QAR',
#     'sName': 'Rials'
# }, {
#     'sISOCode': 'YER',
#     'sName': 'Rials'
# }, {
#     'sISOCode': 'KHR',
#     'sName': 'Riels'
# }, {
#     'sISOCode': 'MYR',
#     'sName': 'Ringgits'
# }, {
#     'sISOCode': 'SAR',
#     'sName': 'Riyals'
# }, {
#     'sISOCode': 'BYR',
#     'sName': 'Rubles'
# }, {
#     'sISOCode': 'RUB',
#     'sName': 'Rubles'
# }, {
#     'sISOCode': 'MVR',
#     'sName': 'Rufiyaa'
# }, {
#     'sISOCode': 'INR',
#     'sName': 'Rupees'
# }, {
#     'sISOCode': 'LKR',
#     'sName': 'Rupees'
# }, {
#     'sISOCode': 'MUR',
#     'sName': 'Rupees'
# }, {
#     'sISOCode': 'PKR',
#     'sName': 'Rupees'
# }, {
#     'sISOCode': 'SCR',
#     'sName': 'Rupees'
# }, {
#     'sISOCode': 'IDR',
#     'sName': 'Rupiahs'
# }, {
#     'sISOCode': 'RWF',
#     'sName': 'Rwanda Francs'
# }, {
#     'sISOCode': 'RSD',
#     'sName': 'Serbian Dinar'
# }, {
#     'sISOCode': 'KES',
#     'sName': 'Shillings'
# }, {
#     'sISOCode': 'SOS',
#     'sName': 'Shillings'
# }, {
#     'sISOCode': 'TZS',
#     'sName': 'Shillings'
# }, {
#     'sISOCode': 'UGX',
#     'sName': 'Shillings'
# }, {
#     'sISOCode': 'XAG',
#     'sName': 'Silver Ounces'
# }, {
#     'sISOCode': 'TJS',
#     'sName': 'Somoni'
# }, {
#     'sISOCode': 'KGS',
#     'sName': 'Soms'
# }, {
#     'sISOCode': 'ZAR',
#     'sName': 'South Africa Rands'
# }, {
#     'sISOCode': 'UZS',
#     'sName': 'Sums'
# }, {
#     'sISOCode': 'CHF',
#     'sName': 'Swiss Francs'
# }, {
#     'sISOCode': 'BDT',
#     'sName': 'Taka'
# }, {
#     'sISOCode': 'WST',
#     'sName': 'Tala'
# }, {
#     'sISOCode': 'KZT',
#     'sName': 'Tenge'
# }, {
#     'sISOCode': 'SIT',
#     'sName': 'Tolars'
# }, {
#     'sISOCode': 'MNT',
#     'sName': 'Tugriks'
# }, {
#     'sISOCode': 'TVD',
#     'sName': 'Tuvalu Dollars'
# }, {
#     'sISOCode': 'VUV',
#     'sName': 'Vatu'
# }, {
#     'sISOCode': 'KPW',
#     'sName': 'Won'
# }, {
#     'sISOCode': 'KRW',
#     'sName': 'Won'
# }, {
#     'sISOCode': 'JPY',
#     'sName': 'Yen'
# }, {
#     'sISOCode': 'CNY',
#     'sName': 'Yuan Renminbi'
# }, {
#     'sISOCode': 'ZWD',
#     'sName': 'Zimbabwe Dollars'
# }, {
#     'sISOCode': 'PLN',
#     'sName': 'Zlotych'
# }]
